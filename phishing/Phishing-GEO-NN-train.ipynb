# %% [markdown]
# # GEO feature-based phishing detection NN

# %% [markdown]
# ## Columns to be removed from training/validation

# %%
disqualified_columns = ["tls_joint_isoitu_policy_crt_count", "rdap_time_from_last_change", "lex_www_flag"]

# %% [markdown]
# ## Feature prefix

# %%
prefix = "geo_"

# %% [markdown]
# # Load Tensorflow and check GPU availability

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.python.client import device_lib

for device in device_lib.list_local_devices():
    print(device.physical_device_desc)
# Out:
# 2024-06-13 03:07:53.166016: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 03:07:53.166041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 03:07:53.166795: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-13 03:07:53.170986: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 03:07:53.731648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:07:00.0, compute capability: 8.9
# 2024-06-13 03:07:54.500353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2327] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1) with core count: 6. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2024-06-13 03:07:54.504881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 6271 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:07:00.0, compute capability: 8.9

# %% [markdown]
# # Load input datasets

# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pandas import DataFrame
from pandas.core.dtypes import common as com
from pyarrow import Table


def union_tables(tables: [pa.Table]) -> pa.Table:
    union_table = tables[0]
    for table in tables[1:]:
        right_not_in_union = union_table.join(right_table=table, keys='domain_name', join_type='right anti',
                                              coalesce_keys=True, use_threads=True)
        union_table = pa.concat_tables([union_table, right_not_in_union])
    return union_table

# #############################################################
# EDIT this to specify benign / malicious datasets to use     #
# #############################################################
benign_dataset_filenames = [
    '../feature-extraction/floor/benign_2312.parquet',
    '../feature-extraction/floor/umbrella_benign_FINISHED.parquet',
]
malicious_dataset_filenames = [
    '../feature-extraction/floor/phishing_4.parquet'
]
# #############################################################
# EDIT this for to set appropriate labels (malware, dga, ...) #
# #############################################################
benign_label = "benign"
malicious_label = "phishing"
# #############################################################

# Unify malicious datasets and benign datasets
schema = (pq.read_table(malicious_dataset_filenames[0])).schema # Use the schema from the first malicious filename
benign_tables = [pq.read_table(filename).cast(schema) for filename in benign_dataset_filenames]
malicious_tables = [pq.read_table(filename).cast(schema) for filename in malicious_dataset_filenames]
malicious = union_tables(malicious_tables)
benign = union_tables(benign_tables)

# Convert pyarrow tables to pandas dataframes
df_benign = benign.to_pandas()
df_malicious = malicious.to_pandas()

# Set appropriate labels
df_benign["label"] = benign_label
df_malicious["label"] = malicious_label
class_map = {benign_label: 0, malicious_label: 1}



# ===================
# AUTO BALANCING !!!
# Subsample benign to match the size of malicious
# df_benign = df_benign.sample(n=len(df_malicious))
# ===================

# Concatentate benign and malicious
df = pd.concat([df_benign, df_malicious])


def cast_timestamp(df: DataFrame):
    """
    Cast timestamp fields to seconds since epoch.
    """
    for col in df.columns:
        if com.is_timedelta64_dtype(df[col]):
            df[col] = df[col].dt.total_seconds()  # This converts timedelta to float (seconds)
        elif com.is_datetime64_any_dtype(df[col]):
            df[col] = df[col].astype(np.int64) // 10**9  # Converts datetime64 to Unix timestamp (seconds)

    return df

df = cast_timestamp(df)

# Handle NaNs
df.fillna(-1, inplace=True)


# SUBSAMPLE (OPTIONAL)
subsample = 1.0 # 1.0 means no subsample
if subsample < 1.0:
    df = df.sample(frac=subsample)

# Drop the domain name column
df.drop("domain_name", axis=1, inplace=True)

# Remove disqualified columns
for column in disqualified_columns:
    if column in df.columns:
        df.drop(column, axis=1, inplace=True)


# Preserve only columns of interest
# Filter columns
df = df.loc[:, df.columns.str.startswith(prefix) | df.columns.isin(['domain_name', 'label'])]


labels = df['label'].apply(lambda x: class_map[x]) # y vector
features = df.drop('label', axis=1).copy() # X matrix

print(f"Total samples: {len(df)}")
print(f"Benign count: {len(df_benign)}")
print(f"Malicious count: {len(df_malicious)}")



df
# Out:
# Total samples: 1001439
# Benign count: 816324
# Malicious count: 185115
#            label  geo_countries_count  geo_continents_count  \
# 0         benign                    1                     1
# 1         benign                    1                     1
# 2         benign                    2                     2
# 3         benign                    1                     1
# 4         benign                    1                     1
# ...          ...                  ...                   ...
# 185110  phishing                    0                     0
# 185111  phishing                    0                     0
# 185112  phishing                    0                     0
# 185113  phishing                    0                     0
# 185114  phishing                    0                     0
#
#         geo_malic_host_country  geo_lat_stdev  geo_lon_stdev  geo_mean_lat  \
# 0                            0       0.000000       0.000000     47.377200
# 1                            0       0.000000       0.000000     47.377200
# 2                            1       4.428575      40.477583     48.124362
# 3                            0       0.000000       0.000000     48.666700
# 4                            0       0.000000       0.000000     48.666700
# ...                        ...            ...            ...           ...
# 185110                       0       0.000000       0.000000      0.000000
# 185111                       0       0.000000       0.000000      0.000000
# 185112                       0       0.000000       0.000000      0.000000
# 185113                       0       0.000000       0.000000      0.000000
# 185114                       0       0.000000       0.000000      0.000000
#
#         geo_mean_lon  geo_min_lat  geo_max_lat  geo_min_lon  geo_max_lon  \
# 0          15.093800      47.3772      47.3772      15.0938      15.0938
# 1          15.093800      47.3772      47.3772      15.0938      15.0938
# 2          -2.894162      37.7510      50.0853     -97.8220      14.4110
# 3          19.500000      48.6667      48.6667      19.5000      19.5000
# 4          19.500000      48.6667      48.6667      19.5000      19.5000
# ...              ...          ...          ...          ...          ...
# 185110      0.000000       0.0000       0.0000       0.0000       0.0000
# 185111      0.000000       0.0000       0.0000       0.0000       0.0000
# 185112      0.000000       0.0000       0.0000       0.0000       0.0000
# 185113      0.000000       0.0000       0.0000       0.0000       0.0000
# 185114      0.000000       0.0000       0.0000       0.0000       0.0000
#
#         geo_lat_range  geo_lon_range  geo_centroid_lat  geo_centroid_lon  \
# 0              0.0000          0.000          71.06580           22.6407
# 1              0.0000          0.000          71.06580           22.6407
# 2             12.3343        112.233          62.79365          -90.6165
# 3              0.0000          0.000          73.00005           29.2500
# 4              0.0000          0.000          73.00005           29.2500
# ...               ...            ...               ...               ...
# 185110         0.0000          0.000           0.00000            0.0000
# 185111         0.0000          0.000           0.00000            0.0000
# 185112         0.0000          0.000           0.00000            0.0000
# 185113         0.0000          0.000           0.00000            0.0000
# 185114         0.0000          0.000           0.00000            0.0000
#
#         geo_estimated_area  geo_continent_hash  geo_countries_hash
# 0                 0.000000                   3                  10
# 1                 0.000000                   3                  10
# 2              1384.315492                   4                 464
# 3                 0.000000                   3                 158
# 4                 0.000000                   3                 158
# ...                    ...                 ...                 ...
# 185110            0.000000                   0                   0
# 185111            0.000000                   0                   0
# 185112            0.000000                   0                   0
# 185113            0.000000                   0                   0
# 185114            0.000000                   0                   0
#
# [1001439 rows x 19 columns]

# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import joblib
 
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(features)
features = pd.DataFrame(scaled_data, columns=features.columns)

# Save the scaler
joblib.dump(scaler, "phishing_geo_nn_scaler.joblib")

pd.set_option('display.max_columns', None)
features
# Out:
#          geo_countries_count  geo_continents_count  geo_malic_host_country  \
# 0                   0.043478              0.142857                     0.0
# 1                   0.043478              0.142857                     0.0
# 2                   0.086957              0.285714                     1.0
# 3                   0.043478              0.142857                     0.0
# 4                   0.043478              0.142857                     0.0
# ...                      ...                   ...                     ...
# 1001434             0.000000              0.000000                     0.0
# 1001435             0.000000              0.000000                     0.0
# 1001436             0.000000              0.000000                     0.0
# 1001437             0.000000              0.000000                     0.0
# 1001438             0.000000              0.000000                     0.0
#
#          geo_lat_stdev  geo_lon_stdev  geo_mean_lat  geo_mean_lon  \
# 0              0.00000       0.000000      0.792614      0.540705
# 1              0.00000       0.000000      0.792614      0.540705
# 2              0.07888       0.248169      0.798410      0.490117
# 3              0.00000       0.000000      0.802616      0.553097
# 4              0.00000       0.000000      0.802616      0.553097
# ...                ...            ...           ...           ...
# 1001434        0.00000       0.000000      0.425150      0.498257
# 1001435        0.00000       0.000000      0.425150      0.498257
# 1001436        0.00000       0.000000      0.425150      0.498257
# 1001437        0.00000       0.000000      0.425150      0.498257
# 1001438        0.00000       0.000000      0.425150      0.498257
#
#          geo_min_lat  geo_max_lat  geo_min_lon  geo_max_lon  geo_lat_range  \
# 0           0.792614     0.792614     0.541928     0.539475       0.000000
# 1           0.792614     0.792614     0.541928     0.539475       0.000000
# 2           0.717952     0.813619     0.225220     0.537550       0.103276
# 3           0.802616     0.802616     0.554287     0.551900       0.000000
# 4           0.802616     0.802616     0.554287     0.551900       0.000000
# ...              ...          ...          ...          ...            ...
# 1001434     0.425150     0.425150     0.499593     0.496913       0.000000
# 1001435     0.425150     0.425150     0.499593     0.496913       0.000000
# 1001436     0.425150     0.425150     0.499593     0.496913       0.000000
# 1001437     0.425150     0.425150     0.499593     0.496913       0.000000
# 1001438     0.425150     0.425150     0.499593     0.496913       0.000000
#
#          geo_lon_range  geo_centroid_lat  geo_centroid_lon  \
# 0             0.000000          0.792614          0.541113
# 1             0.000000          0.792614          0.541113
# 2             0.320169          0.749841          0.328959
# 3             0.000000          0.802616          0.553494
# 4             0.000000          0.802616          0.553494
# ...                ...               ...               ...
# 1001434       0.000000          0.425150          0.498703
# 1001435       0.000000          0.425150          0.498703
# 1001436       0.000000          0.425150          0.498703
# 1001437       0.000000          0.425150          0.498703
# 1001438       0.000000          0.425150          0.498703
#
#          geo_estimated_area  geo_continent_hash  geo_countries_hash
# 0                  0.000000            0.142857        1.257941e-08
# 1                  0.000000            0.142857        1.257941e-08
# 2                  0.042632            0.190476        5.836848e-07
# 3                  0.000000            0.142857        1.987547e-07
# 4                  0.000000            0.142857        1.987547e-07
# ...                     ...                 ...                 ...
# 1001434            0.000000            0.000000        0.000000e+00
# 1001435            0.000000            0.000000        0.000000e+00
# 1001436            0.000000            0.000000        0.000000e+00
# 1001437            0.000000            0.000000        0.000000e+00
# 1001438            0.000000            0.000000        0.000000e+00
#
# [1001439 rows x 18 columns]

# %% [markdown]
# # Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
  features,
  labels,
  test_size=0.2,
  random_state=42,
  shuffle=True, 
  stratify=labels
)

# %% [markdown]
# # Define the NN model

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(18,)))
#model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=[Precision(), Recall(), AUC()]
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 64)                1216
#
#  batch_normalization_4 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 32)                1056
#
#  dense_19 (Dense)            (None, 32)                1056
#
#  dense_20 (Dense)            (None, 32)                1056
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_21 (Dense)            (None, 32)                1056
#
#  dense_22 (Dense)            (None, 16)                528
#
#  dense_23 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 8449 (33.00 KB)
# Trainable params: 8257 (32.25 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
settings = {
    # ALL LAYERS
    'MAX_NEURONS': 10,
}

from keras_visualizer import visualizer
from keras import models, layers

visualizer(model, file_format='png', settings=settings, view=True)

from IPython.display import Image
Image(filename='graph.png')

# %% [markdown]
# # Train the model

# %%
from sklearn.utils import class_weight

from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping criteria
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Calculate class weights
class_weights = {0: 1.0, 1: 1.0} 

history = model.fit(
    X_train,
    Y_train,
    batch_size=512,
    epochs=70,
    validation_data=(X_test, Y_test),  # Provide validation data
    class_weight=class_weights,  # Apply class weights here
    callbacks=[early_stopping]  # Add early stopping callback
)
# Out:
# Epoch 1/70
# 1565/1565 [==============================] - 15s 8ms/step - loss: 0.4218 - precision_2: 0.6154 - recall_2: 0.0247 - auc_2: 0.7395 - val_loss: 0.4058 - val_precision_2: 0.5748 - val_recall_2: 0.0624 - val_auc_2: 0.7668
# Epoch 2/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.4043 - precision_2: 0.6175 - recall_2: 0.0576 - auc_2: 0.7689 - val_loss: 0.3986 - val_precision_2: 0.6101 - val_recall_2: 0.0793 - val_auc_2: 0.7794
# Epoch 3/70
# 1565/1565 [==============================] - 11s 7ms/step - loss: 0.3997 - precision_2: 0.6130 - recall_2: 0.0732 - auc_2: 0.7763 - val_loss: 0.3936 - val_precision_2: 0.5890 - val_recall_2: 0.1060 - val_auc_2: 0.7884
# Epoch 4/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3964 - precision_2: 0.6225 - recall_2: 0.0857 - auc_2: 0.7814 - val_loss: 0.3905 - val_precision_2: 0.5839 - val_recall_2: 0.1369 - val_auc_2: 0.7921
# Epoch 5/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.3935 - precision_2: 0.6341 - recall_2: 0.1012 - auc_2: 0.7855 - val_loss: 0.4032 - val_precision_2: 0.6462 - val_recall_2: 0.0549 - val_auc_2: 0.7682
# Epoch 6/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3914 - precision_2: 0.6428 - recall_2: 0.1108 - auc_2: 0.7882 - val_loss: 0.3940 - val_precision_2: 0.6273 - val_recall_2: 0.0787 - val_auc_2: 0.7807
# Epoch 7/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3898 - precision_2: 0.6558 - recall_2: 0.1152 - auc_2: 0.7904 - val_loss: 0.3850 - val_precision_2: 0.6774 - val_recall_2: 0.1146 - val_auc_2: 0.7987
# Epoch 8/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3882 - precision_2: 0.6613 - recall_2: 0.1199 - auc_2: 0.7926 - val_loss: 0.3962 - val_precision_2: 0.6178 - val_recall_2: 0.0789 - val_auc_2: 0.7818
# Epoch 9/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3868 - precision_2: 0.6680 - recall_2: 0.1202 - auc_2: 0.7942 - val_loss: 0.3830 - val_precision_2: 0.6136 - val_recall_2: 0.1651 - val_auc_2: 0.8015
# Epoch 10/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.3861 - precision_2: 0.6641 - recall_2: 0.1263 - auc_2: 0.7955 - val_loss: 0.3816 - val_precision_2: 0.6965 - val_recall_2: 0.1013 - val_auc_2: 0.8056
# Epoch 11/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3855 - precision_2: 0.6693 - recall_2: 0.1249 - auc_2: 0.7961 - val_loss: 0.3827 - val_precision_2: 0.6798 - val_recall_2: 0.1067 - val_auc_2: 0.8014
# Epoch 12/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3845 - precision_2: 0.6716 - recall_2: 0.1269 - auc_2: 0.7976 - val_loss: 0.3793 - val_precision_2: 0.6528 - val_recall_2: 0.1586 - val_auc_2: 0.8040
# Epoch 13/70
# 1565/1565 [==============================] - 13s 9ms/step - loss: 0.3841 - precision_2: 0.6717 - recall_2: 0.1281 - auc_2: 0.7982 - val_loss: 0.3822 - val_precision_2: 0.7569 - val_recall_2: 0.0883 - val_auc_2: 0.7984
# Epoch 14/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3840 - precision_2: 0.6707 - recall_2: 0.1253 - auc_2: 0.7981 - val_loss: 0.3806 - val_precision_2: 0.6677 - val_recall_2: 0.1540 - val_auc_2: 0.8016
# Epoch 15/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.3830 - precision_2: 0.6705 - recall_2: 0.1316 - auc_2: 0.7995 - val_loss: 0.3862 - val_precision_2: 0.7013 - val_recall_2: 0.1096 - val_auc_2: 0.7960
# Epoch 16/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3823 - precision_2: 0.6712 - recall_2: 0.1308 - auc_2: 0.8006 - val_loss: 0.3778 - val_precision_2: 0.6652 - val_recall_2: 0.1276 - val_auc_2: 0.8087
# Epoch 17/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3812 - precision_2: 0.6695 - recall_2: 0.1344 - auc_2: 0.8025 - val_loss: 0.3746 - val_precision_2: 0.6485 - val_recall_2: 0.1614 - val_auc_2: 0.8113
# Epoch 18/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3803 - precision_2: 0.6756 - recall_2: 0.1371 - auc_2: 0.8035 - val_loss: 0.3830 - val_precision_2: 0.6625 - val_recall_2: 0.1531 - val_auc_2: 0.8026
# Epoch 19/70
# 1565/1565 [==============================] - 11s 7ms/step - loss: 0.3795 - precision_2: 0.6744 - recall_2: 0.1396 - auc_2: 0.8044 - val_loss: 0.3735 - val_precision_2: 0.6912 - val_recall_2: 0.1509 - val_auc_2: 0.8140
# Epoch 20/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3788 - precision_2: 0.6773 - recall_2: 0.1410 - auc_2: 0.8054 - val_loss: 0.3704 - val_precision_2: 0.6918 - val_recall_2: 0.1434 - val_auc_2: 0.8162
# Epoch 21/70
# 1565/1565 [==============================] - 11s 7ms/step - loss: 0.3781 - precision_2: 0.6757 - recall_2: 0.1429 - auc_2: 0.8062 - val_loss: 0.3998 - val_precision_2: 0.6459 - val_recall_2: 0.0624 - val_auc_2: 0.7751
# Epoch 22/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3777 - precision_2: 0.6784 - recall_2: 0.1430 - auc_2: 0.8068 - val_loss: 0.3952 - val_precision_2: 0.6605 - val_recall_2: 0.0603 - val_auc_2: 0.7790
# Epoch 23/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.3775 - precision_2: 0.6791 - recall_2: 0.1413 - auc_2: 0.8073 - val_loss: 0.3848 - val_precision_2: 0.6619 - val_recall_2: 0.1083 - val_auc_2: 0.7997
# Epoch 24/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3764 - precision_2: 0.6810 - recall_2: 0.1469 - auc_2: 0.8084 - val_loss: 0.3740 - val_precision_2: 0.6919 - val_recall_2: 0.1434 - val_auc_2: 0.8119
# Epoch 25/70
# 1565/1565 [==============================] - 14s 9ms/step - loss: 0.3764 - precision_2: 0.6773 - recall_2: 0.1445 - auc_2: 0.8086 - val_loss: 0.3744 - val_precision_2: 0.6667 - val_recall_2: 0.1077 - val_auc_2: 0.8124
# Epoch 26/70
# 1565/1565 [==============================] - 15s 10ms/step - loss: 0.3760 - precision_2: 0.6847 - recall_2: 0.1450 - auc_2: 0.8090 - val_loss: 0.3783 - val_precision_2: 0.6709 - val_recall_2: 0.1237 - val_auc_2: 0.8063
# Epoch 27/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3764 - precision_2: 0.6786 - recall_2: 0.1457 - auc_2: 0.8086 - val_loss: 0.3879 - val_precision_2: 0.6875 - val_recall_2: 0.0881 - val_auc_2: 0.7943
# Epoch 28/70
# 1565/1565 [==============================] - 13s 8ms/step - loss: 0.3764 - precision_2: 0.6766 - recall_2: 0.1482 - auc_2: 0.8086 - val_loss: 0.3730 - val_precision_2: 0.7507 - val_recall_2: 0.1372 - val_auc_2: 0.8125
# Epoch 29/70
# 1565/1565 [==============================] - 12s 8ms/step - loss: 0.3758 - precision_2: 0.6764 - recall_2: 0.1481 - auc_2: 0.8095 - val_loss: 0.3747 - val_precision_2: 0.6624 - val_recall_2: 0.1361 - val_auc_2: 0.8123
# Epoch 30/70
# 1565/1565 [==============================] - 13s 9ms/step - loss: 0.3750 - precision_2: 0.6781 - recall_2: 0.1491 - auc_2: 0.8104 - val_loss: 0.3887 - val_precision_2: 0.6732 - val_recall_2: 0.1047 - val_auc_2: 0.7909

# %% [markdown]
# # Save the model

# %%
model.save('phishing_geo_nn_model.keras')

# %% [markdown]
# # Display training results

# %%
def get_metric(history, metric_name):
    if metric_name in history.history:
        return history.history[metric_name]
    elif f"{metric_name}_1" in history.history:
        return history.history[f"{metric_name}_1"]
    elif f"{metric_name}_2" in history.history:
        return history.history[f"{metric_name}_2"]
    else:
        raise KeyError(f"Metric {metric_name} not found in history.")

epoch_losses = get_metric(history, 'loss')
epoch_val_losses = get_metric(history, 'val_loss')
epoch_accuracies = get_metric(history, 'auc')
epoch_val_accuracies = get_metric(history, 'val_auc')
epoch_precisions = get_metric(history, 'precision')
epoch_val_precisions = get_metric(history, 'val_precision')
epoch_recalls = get_metric(history, 'recall')
epoch_val_recalls = get_metric(history, 'val_recall')

# Calculate F1 score
epoch_f1s = [2 * (p * r) / (p + r) for p, r in zip(epoch_precisions, epoch_recalls)]
epoch_val_f1s = [2 * (p * r) / (p + r) for p, r in zip(epoch_val_precisions, epoch_val_recalls)]

import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))

# Plot for Loss
plt.subplot(2, 3, 1)
plt.plot(epoch_losses, linestyle='--', marker='o', color='b', label='Training Loss')
plt.plot(epoch_val_losses, linestyle='--', marker='o', color='r', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.grid(True)

# Plot for AUC (as a proxy for Accuracy)
plt.subplot(2, 3, 2)
plt.plot(epoch_accuracies, linestyle='--', marker='o', color='#ff7f0e', label='Training AUC')
plt.plot(epoch_val_accuracies, linestyle='--', marker='o', color='r', label='Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.title('AUC (Accuracy)')
plt.legend()
plt.grid(True)

# Plot for Precision
plt.subplot(2, 3, 3)
plt.plot(epoch_precisions, linestyle='--', marker='o', color='g', label='Training Precision')
plt.plot(epoch_val_precisions, linestyle='--', marker='o', color='r', label='Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.title('Precision')
plt.legend()
plt.grid(True)

# Plot for Recall
plt.subplot(2, 3, 4)
plt.plot(epoch_recalls, linestyle='--', marker='o', color='c', label='Training Recall')
plt.plot(epoch_val_recalls, linestyle='--', marker='o', color='r', label='Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.title('Recall')
plt.legend()
plt.grid(True)

# Plot for F1 Score
plt.subplot(2, 3, 5)
plt.plot(epoch_f1s, linestyle='--', marker='o', color='m', label='Training F1 Score')
plt.plot(epoch_val_f1s, linestyle='--', marker='o', color='r', label='Validation F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Score')
plt.legend()
plt.grid(True)

plt.suptitle('NN Training Progress', fontsize=16, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Save the figure
plt.savefig('nn_training_progress.png', dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Evaluate the model
loss_and_metrics = model.evaluate(X_test, Y_test)
print('Loss = ', loss_and_metrics[0])
print('Accuracy = ', loss_and_metrics[1])

# Generate predictions
Y_pred = model.predict(X_test)
Y_pred = np.round(Y_pred).astype(int)  # Convert probabilities to binary predictions

# Calculate additional metrics
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)

# False Positive Rate
tn, fp, fn, tp = cm.ravel()
fpr = fp / (fp + tn)

# Display the metrics
print('\n=== RESULTS ===')
print(classification_report(Y_test, Y_pred, target_names=['Benign', 'Malicious'], digits=4))
print('False Positive Rate =', fpr)


# Display the confusion matrix
print('\nConfusion Matrix:')
print(cm)

# Optionally, plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(7, 7))  # Increase figure size for better readability
disp.plot(ax=ax, values_format='d')
for labels in disp.text_:
    for label in labels:
        label.set_fontsize(18) 
plt.show()
# Out:
# 6259/6259 [==============================] - 9s 1ms/step - loss: 0.3704 - precision_2: 0.6918 - recall_2: 0.1434 - auc_2: 0.8162
# Loss =  0.37037190794944763
# Accuracy =  0.6917665600776672
# 6259/6259 [==============================] - 6s 1ms/step
#
# === RESULTS ===
#               precision    recall  f1-score   support
#
#       Benign     0.8354    0.9855    0.9042    163265
#    Malicious     0.6918    0.1434    0.2376     37023
#
#     accuracy                         0.8299    200288
#    macro avg     0.7636    0.5645    0.5709    200288
# weighted avg     0.8088    0.8299    0.7810    200288
#
# False Positive Rate = 0.014491777172082198
#
# Confusion Matrix:
# [[160899   2366]
#  [ 31713   5310]]

# %% [markdown]
# # Feature Importance Analysis

# %%
analyze_feature_importance = True

if analyze_feature_importance:
    
    import shap
    
    # Ensure that X_train and X_test are DataFrames with the correct column names
    # You can set the column names from the 'features' DataFrame like this:
    X_train.columns = features.columns
    X_test.columns = features.columns
    
    n_samples = 1000
    
    # Convert your training set to a NumPy format if it's not already
    background = X_train[:n_samples].to_numpy()
    
    # Use the generic SHAP Explainer interface
    explainer = shap.Explainer(model, background)
    
    # Generate SHAP values for the test set
    shap_values = explainer(X_test[:n_samples].to_numpy())
    
    # Plotting the summary plot for feature importance
    # Use the column names from the 'features' DataFrame as the feature names
    shap.summary_plot(shap_values.values, X_test[:n_samples], feature_names=features.columns, max_display=30)
# Out:
# Permutation explainer: 1001it [01:24, 10.47it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# # Validate the model on a separate Validation dataset

# %%
import pyarrow.parquet as pq
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import joblib
from tensorflow.keras.models import load_model
from pandas.core.dtypes import common as com
import numpy as np

def cast_timestamp(df: pd.DataFrame):
    """
    Cast timestamp fields to seconds since epoch.
    """
    for col in df.columns:
        if com.is_timedelta64_dtype(df[col]):
            df[col] = df[col].dt.total_seconds()  # This converts timedelta to float (seconds)
        elif com.is_datetime64_any_dtype(df[col]):
            df[col] = df[col].astype(np.int64) // 10**9  # Converts datetime64 to Unix timestamp (seconds)
    return df

# Load the validation dataset
validation_dataset_filename = '../testdata/validation_phishing.parquet'
df_validation = pq.read_table(validation_dataset_filename).to_pandas()

# Cast timestamps and handle NaNs
df_validation = cast_timestamp(df_validation)
df_validation.fillna(-1, inplace=True)

# Remove disqualified columns
for column in disqualified_columns:
    if column in df_validation.columns:
        df_validation.drop(column, axis=1, inplace=True)

# Preserve only columns of interest
df_validation = df_validation.loc[:, df_validation.columns.str.startswith(prefix) | df_validation.columns.isin(['domain_name', 'label'])]

# Map the labels
df_validation['label'] = df_validation['label'].map({'benign': 0, 'phishing': 1})

# Extract features and labels
X_val = df_validation.drop(['label', 'domain_name'], axis=1)
y_val = df_validation['label']

# Load the scaler
scaler = joblib.load("phishing_geo_nn_scaler.joblib")

# Scale the features
X_val_scaled = scaler.transform(X_val)

# Load the trained model
model = load_model('phishing_geo_nn_model.keras')

# Make predictions
y_prob = model.predict(X_val_scaled).flatten()
y_pred = (y_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_val, y_pred)
weighted_accuracy = (accuracy_score(y_val[y_val == 0], y_pred[y_val == 0]) + accuracy_score(y_val[y_val == 1], y_pred[y_val == 1])) / 2
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
false_positive_rate = fp / (fp + tn)

# Display metrics
print(f'Accuracy: {accuracy}')
print(f'Weighted Accuracy: {weighted_accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'False Positive Rate: {false_positive_rate}')

# Display confusion matrix
cm = confusion_matrix(y_val, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['benign', 'phishing'])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# Identify misclassified domain names
misclassified = df_validation[y_val != y_pred]
misclassified_domains = misclassified['domain_name'].tolist()
print(f'Misclassified domains: {misclassified_domains}')
# Out:
# 78/78 [==============================] - 0s 1ms/step
# Accuracy: 0.8931451612903226
# Weighted Accuracy: 0.6019188872130048
# Precision: 0.5210084033613446
# Recall: 0.22962962962962963
# F1 Score: 0.31876606683804626
# False Positive Rate: 0.025791855203619908
# Misclassified domains: ['bt-104190.weeblysite.com', 'www.manners-biz.com', 'ancient-mouse-7f8e.lizip.workers.dev', 'chat.hosi.co', '3793svxn.computer-mod-s.tech', 'bt-101281-109546.weeblysite.com', 'ijcrt.org', '0162xygl.computer-mod-s.tech', 'ws-keyboard.shouji.sogou.com', 'www.accouappel.accoutenness.com', 'pub-d85936a61b694753a8b489011149f7b5.r2.dev', 'www.chaiwen.net', 'www.mulinlab.org', 'fodi.caijimoyu.eu.org', '1456ubmz.computer-mod-s.tech', '0fd.me', 'shrimp.wtf', 'www.niwens.com', '9172mzgd.computer-mod-s.tech', 'www.wangchaofeng.com', 'new21jewqgeneratedlinksfnaiso4basdjhkadascloud.pages.dev', 'att-105809.square.site', 'coinbase-pro-log.godaddysites.com', 'pub-5a533b66fc614517b92f5493ea982e93.r2.dev', 'att-106770.weeblysite.com', 'hp18.pages.dev', 'lodgerbnbaproving550901.com', 'att-106642-104305.weeblysite.com', 'pub-feedbe664d4644f987dafae09faf8476.r2.dev', 'snikirakic.wixsite.com', 'reviewholdreviewho.wixsite.com', 'yfkh63piv9o5x32y2h5pund3ovmy455f9axfuczfofxynqwjgwk80jtha4.pages.dev', 'www.magicbath.co.in', 'v2cf01.pages.dev', 'pub-38b81a81487b452d86ecfd3a873e5640.r2.dev', 'imken.pro', 't5rzutcijpbut6o84hd09xa2kxh268l011g2m3oz8zqv8uc9g72bmk7n15.pages.dev', 'liyanchen.pages.dev', 'x485m-7bxypph3imq-vfim3gtrqoz88w2nwxcgovsf1yqjtoku1gej8d11.pages.dev', 'duguangge.com', 'claim-notcoin.pages.dev', 'cdq.ayb.mybluehost.me', 'hty-ce3.pages.dev', 'attnet-104176.weeblysite.com', 'businesscentersc.pages.dev', '2688tsay.computer-mod-s.tech', 'bt-business-app-e213d8.webflow.io', 'marutiminchem.com', 'iah3xre3mcz8d6tzu1tsmc1dtv7waebs327bp-h-9nhq922cv0i-autq86.pages.dev', 'heoo2.511110.xyz', 'f002.backblazeb2.com', 'd.la3-c2-ia2.salesforceliveagent.com', 'arbearssgrounds.wixsite.com', 'diversifiedglobalproducts.com', 'at-mail-102779.weeblysite.com', 'cf.bmzk.link', 'greenanymorewaytogo.florece4.workers.dev', 'pub-2b4ee549eae54c3ab7f6c0c2ab24bbf8.r2.dev', 'fuorifrigo.com', 'telegprxm.work', 'namaskarmahra.com', 'bannedbookslist.com', 'pub-0a244b22861d456681dab3d4e696448b.r2.dev', 'zdy.yong96.link', 'a6-d9r.pages.dev', 'mswap.bbd.sh', 'wuyier102.pxrocgr.workers.dev', 'securitycheckios.com', 'upfupf.columbiauniversityinpictures.com', 'sgfhnbg.pages.dev', 't0kanpoaket.biz', 'temperate-kangaroo-kw0hgq.mystrikingly.com', 'attnet-106864.weeblysite.com', 'www.industry-boiler.com', 'www.benyuans.com', 'barosan77.tripod.com', 'cryosparc.com', 'official-telegram-meetandsexx.pages.dev', 'a645f1800842942115c2151e8de5377e084c8f51fa0a7e4b97f405de43.pages.dev', 'www.facebookes.com', 'fwuaiaiuewctcresrytuieowepkmnbbvcs4srdfgyuwvdiyks.yolasite.com', 'wwe.vfghjfg45gfh.dns-dynamic.net', 'tok2npo2ket.top', 'item-list22119.atwebpages.com', 'app.thetodo.net', 'steinerjj1.wixsite.com', 'at-ts-groovy-site-ab70ba.webflow.io', 'x22-1uo.pages.dev', 'securchase.verify.englishclassroom.com.br', '4419ohts.computer-mod-s.tech', 'swap.testnet.tabichain.com', 'pacificobdpec.ac-page.com', 'cookingpastaready.com', 'momba.dev', 'xiucaixs.com', 'jis-5rl.pages.dev', 'gd-game01.heyyogame.com', 'ghdf.pages.dev', 'veiwmailfhggffdsdgfghjt.lritz31.workers.dev', '3102jtnu.computer-mod-s.tech', 'www.erotikportal.vip', 'ima3vpaid.appspot.com', 'biz.skys.cloudns.biz', 'scdn.vnecdn.net', 'purring-warp-plier.glitch.me', 'imttolkent.com', '1r5sapply.com', 'beleza-naturais-kosmetikshop.de', 'pool-nftsbox.web.app', 'nirvanabiogenics.com', 'att-107124-109117.square.site', 'www.zumusw.com', 'bafybeidvkboe27s67yrcdr74gfgwh26fhiidh2l53rmh55mvg7wkpgnlie.ipfs.dweb.link', '8966msah.computer-mod-s.tech', 'tdrm.ydns.eu', 's44-ddmam-dom41n.s3.us-east-2.amazonaws.com', 'psychotoons.org', 'yorkxiaobaibai.xyz', 'd.la2-c2-hnd.salesforceliveagent.com', 'tcaventuregroup.com', '365bbz.com', 'conway-hash-portfolio.vercel.app', 'fdge5vpb2ta0yzwymu8kwgbcuitpy2gz4uklaoil1vtg1903napdh6zf4i.pages.dev', 'teamtepei.com', 'cse.google.fi', 'private-message.pages.dev', 'kewiwi9125.wixsite.com', 'jedikeieuj.weebly.com', 'cableone.co.ke', 'jewelhunterauth.linkdesks.net', '2969zsgc.computer-mod-s.tech', 'bt-bu ...

# %% [markdown]
# # Make test predictions

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import joblib
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pyarrow import Table

# Load the model and scaler
model = load_model('dga_binary_model.keras')
scaler = joblib.load("dga_binary_scaler.joblib")

# #############################################################
# EDIT this to specify benign / malicious datasets to use     #
# #############################################################
benign_dataset_filenames = [
    '../feature-extraction/floor/benign_2312_anonymized.parquet',
    '../feature-extraction/floor/umbrella_benign_FINISHED.parquet',
]
malicious_dataset_filenames = [
    '../feature-extraction/floor/lex-dga-830k-pick.parquet'
]
# #############################################################
# EDIT this for to set appropriate labels (malware, dga, ...) #
# #############################################################
benign_label = "benign"
malicious_label = "dga"
# #############################################################

def union_tables(tables: [pa.Table]) -> pa.Table:
    union_table = tables[0]
    for table in tables[1:]:
        right_not_in_union = union_table.join(right_table=table, keys='domain_name', join_type='right anti',
                                              coalesce_keys=True, use_threads=True)
        union_table = pa.concat_tables([union_table, right_not_in_union])
    return union_table

# Unify malicious datasets and benign datasets
schema = (pq.read_table(malicious_dataset_filenames[0])).schema # Use the schema from the first malicious filename
benign_tables = [pq.read_table(filename).cast(schema) for filename in benign_dataset_filenames]
malicious_tables = [pq.read_table(filename).cast(schema) for filename in malicious_dataset_filenames]
malicious = union_tables(malicious_tables)
benign = union_tables(benign_tables)

# Convert pyarrow tables to pandas dataframes
df_benign = benign.to_pandas()
df_malicious = malicious.to_pandas()

# Set appropriate labels
df_benign["label"] = benign_label
df_malicious["label"] = malicious_label
class_map = {benign_label: 0, malicious_label: 1}

# Concatentate benign and malicious
test_df = pd.concat([df_benign, df_malicious])

# Handle NaNs
test_df.fillna(-1, inplace=True)


# Take only N random samples
N = 500
test_df = test_df.sample(n=N, random_state=42)

total_predictions = 0
correct_predictions = 0

for index, row in test_df.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    # Drop "domain_name" and "label" columns
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)

     # Scale the feature vector using the loaded scaler
    scaled_feature_vector = scaler.transform(feature_vector)
    
    # Perform prediction
    prediction = model.predict(scaled_feature_vector, verbose=0)
    
    # Extract the predicted class
    predicted_label = "benign" if prediction < 0.5 else "dga"
    
    # Check if the prediction was correct
    if original_label == predicted_label:
        correct_predictions += 1
    
    total_predictions += 1
    
    # Print the result
    result="WRONG"
    if predicted_label == original_label:
        result="OK"
        
    pred_disp = "!!! DGA !!!"
    if predicted_label == "benign":
        pred_disp = "BENIGN"
        
    
    print(f"{result} | {domain_name} ({original_label}), Predicted: {pred_disp}, Prob: {prediction}")

# Calculate accuracy
accuracy = correct_predictions / total_predictions
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[26], line 12
#       9 from pyarrow import Table
#      11 # Load the model and scaler
# ---> 12 model = load_model('dga_binary_model.keras')
#      13 scaler = joblib.load("dga_binary_scaler.joblib")
#      15 # #############################################################
#      16 # EDIT this to specify benign / malicious datasets to use     #
#      17 # #############################################################
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/saving/legacy/save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at dga_binary_model.keras
