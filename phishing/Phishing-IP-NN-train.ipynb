# %% [markdown]
# # IP feature-based phishing detection NN

# %% [markdown]
# ## Columns to be removed from training/validation

# %%
disqualified_columns = ["tls_joint_isoitu_policy_crt_count", "rdap_time_from_last_change", "lex_www_flag"]

# %% [markdown]
# ## Feature prefix

# %%
prefix = "ip_"

# %% [markdown]
# # Load Tensorflow and check GPU availability

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.python.client import device_lib

for device in device_lib.list_local_devices():
    print(device.physical_device_desc)
# Out:
# 2024-06-13 15:03:13.026902: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 15:03:13.026941: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 15:03:13.027742: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-13 15:03:13.031812: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 15:03:13.621863: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:07:00.0, compute capability: 8.9
# 2024-06-13 15:03:14.395176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2327] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1) with core count: 6. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2024-06-13 15:03:14.399738: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 1168 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:07:00.0, compute capability: 8.9

# %% [markdown]
# # Load input datasets

# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pandas import DataFrame
from pandas.core.dtypes import common as com
from pyarrow import Table


def union_tables(tables: [pa.Table]) -> pa.Table:
    union_table = tables[0]
    for table in tables[1:]:
        right_not_in_union = union_table.join(right_table=table, keys='domain_name', join_type='right anti',
                                              coalesce_keys=True, use_threads=True)
        union_table = pa.concat_tables([union_table, right_not_in_union])
    return union_table

# #############################################################
# EDIT this to specify benign / malicious datasets to use     #
# #############################################################
benign_dataset_filenames = [
    '../feature-extraction/floor/benign_2312.parquet',
    '../feature-extraction/floor/umbrella_benign_FINISHED.parquet',
]
malicious_dataset_filenames = [
    '../feature-extraction/floor/phishing_4.parquet'
]
# #############################################################
# EDIT this for to set appropriate labels (malware, dga, ...) #
# #############################################################
benign_label = "benign"
malicious_label = "phishing"
# #############################################################

# Unify malicious datasets and benign datasets
schema = (pq.read_table(malicious_dataset_filenames[0])).schema # Use the schema from the first malicious filename
benign_tables = [pq.read_table(filename).cast(schema) for filename in benign_dataset_filenames]
malicious_tables = [pq.read_table(filename).cast(schema) for filename in malicious_dataset_filenames]
malicious = union_tables(malicious_tables)
benign = union_tables(benign_tables)

# Convert pyarrow tables to pandas dataframes
df_benign = benign.to_pandas()
df_malicious = malicious.to_pandas()

# Set appropriate labels
df_benign["label"] = benign_label
df_malicious["label"] = malicious_label
class_map = {benign_label: 0, malicious_label: 1}



# ===================
# AUTO BALANCING !!!
# Subsample benign to match the size of malicious
# df_benign = df_benign.sample(n=len(df_malicious))
# ===================

# Concatentate benign and malicious
df = pd.concat([df_benign, df_malicious])


def cast_timestamp(df: DataFrame):
    """
    Cast timestamp fields to seconds since epoch.
    """
    for col in df.columns:
        if com.is_timedelta64_dtype(df[col]):
            df[col] = df[col].dt.total_seconds()  # This converts timedelta to float (seconds)
        elif com.is_datetime64_any_dtype(df[col]):
            df[col] = df[col].astype(np.int64) // 10**9  # Converts datetime64 to Unix timestamp (seconds)

    return df

df = cast_timestamp(df)

# Handle NaNs
df.fillna(-1, inplace=True)


# SUBSAMPLE (OPTIONAL)
subsample = 1.0 # 1.0 means no subsample
if subsample < 1.0:
    df = df.sample(frac=subsample)

# Drop the domain name column
df.drop("domain_name", axis=1, inplace=True)

# Remove disqualified columns
for column in disqualified_columns:
    if column in df.columns:
        df.drop(column, axis=1, inplace=True)


# Preserve only columns of interest
# Filter columns
df = df.loc[:, df.columns.str.startswith(prefix) | df.columns.isin(['domain_name', 'label'])]


labels = df['label'].apply(lambda x: class_map[x]) # y vector
features = df.drop('label', axis=1).copy() # X matrix

print(f"Total samples: {len(df)}")
print(f"Benign count: {len(df_benign)}")
print(f"Malicious count: {len(df_malicious)}")



df
# Out:
# Total samples: 1001439
# Benign count: 816324
# Malicious count: 185115
#            label  ip_count  ip_mean_average_rtt  ip_v4_ratio  \
# 0         benign         1             0.000000          0.0
# 1         benign         1             0.000000          0.0
# 2         benign        13             2.049538          0.5
# 3         benign         1             0.000000          1.0
# 4         benign         1             0.000000          1.0
# ...          ...       ...                  ...          ...
# 185110  phishing         2             4.531000          1.0
# 185111  phishing         6           104.286500          1.0
# 185112  phishing        16             4.357625          0.5
# 185113  phishing         2             4.304500          1.0
# 185114  phishing         6             0.000000          0.0
#
#         ip_a_aaaa_to_all_ratio  ip_entropy  ip_as_address_entropy  \
# 0                     0.000000   -0.000000              -0.000000
# 1                     0.000000   -0.000000              -0.000000
# 2                     0.153846    3.695074               3.695074
# 3                     1.000000   -0.000000              -0.000000
# 4                     1.000000   -0.000000              -0.000000
# ...                        ...         ...                    ...
# 185110                1.000000    1.000000               1.000000
# 185111                1.000000    2.584963               1.792481
# 185112                0.250000    4.500000               4.250000
# 185113                1.000000    1.000000               1.000000
# 185114                0.000000    1.584963              -0.000000
#
#         ip_asn_entropy  ip_distinct_as_count
# 0            -0.000000                   1.0
# 1            -0.000000                   1.0
# 2             1.198184                   3.0
# 3            -0.000000                   1.0
# 4            -0.000000                   1.0
# ...                ...                   ...
# 185110       -0.000000                   1.0
# 185111       -0.000000                   1.0
# 185112       -0.000000                   1.0
# 185113       -0.000000                   1.0
# 185114       -0.000000                   1.0
#
# [1001439 rows x 9 columns]

# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import joblib
 
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(features)
features = pd.DataFrame(scaled_data, columns=features.columns)

# Save the scaler
joblib.dump(scaler, "phishing_ip_nn_scaler.joblib")

pd.set_option('display.max_columns', None)
features
# Out:
#          ip_count  ip_mean_average_rtt  ip_v4_ratio  ip_a_aaaa_to_all_ratio  \
# 0        0.001393             0.000375          0.0                0.000000
# 1        0.001393             0.000375          0.0                0.000000
# 2        0.018106             0.001143          0.5                0.153846
# 3        0.001393             0.000375          1.0                1.000000
# 4        0.001393             0.000375          1.0                1.000000
# ...           ...                  ...          ...                     ...
# 1001434  0.002786             0.002074          1.0                1.000000
# 1001435  0.008357             0.039472          1.0                1.000000
# 1001436  0.022284             0.002009          0.5                0.250000
# 1001437  0.002786             0.001989          1.0                1.000000
# 1001438  0.008357             0.000375          0.0                0.000000
#
#          ip_entropy  ip_as_address_entropy  ip_asn_entropy  \
# 0          0.000000               0.098893        0.158360
# 1          0.000000               0.098893        0.158360
# 2          0.388622               0.464312        0.348105
# 3          0.000000               0.098893        0.158360
# 4          0.000000               0.098893        0.158360
# ...             ...                    ...             ...
# 1001434    0.105173               0.197787        0.158360
# 1001435    0.271868               0.276158        0.158360
# 1001436    0.473278               0.519190        0.158360
# 1001437    0.105173               0.197787        0.158360
# 1001438    0.166695               0.098893        0.158360
#
#          ip_distinct_as_count
# 0                    0.044444
# 1                    0.044444
# 2                    0.088889
# 3                    0.044444
# 4                    0.044444
# ...                       ...
# 1001434              0.044444
# 1001435              0.044444
# 1001436              0.044444
# 1001437              0.044444
# 1001438              0.044444
#
# [1001439 rows x 8 columns]

# %% [markdown]
# # Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
  features,
  labels,
  test_size=0.2,
  random_state=42,
  shuffle=True, 
  stratify=labels
)

# %% [markdown]
# # Define the NN model

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(8,)))
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=[Precision(), Recall(), AUC()]
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 8)                 72
#
#  dense_8 (Dense)             (None, 16)                144
#
#  batch_normalization_2 (Bat  (None, 16)                64
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 16)                272
#
#  dense_10 (Dense)            (None, 32)                544
#
#  dense_11 (Dense)            (None, 32)                1056
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 3881 (15.16 KB)
# Trainable params: 3785 (14.79 KB)
# Non-trainable params: 96 (384.00 Byte)
# _________________________________________________________________

# %%
settings = {
    # ALL LAYERS
    'MAX_NEURONS': 10,
}

from keras_visualizer import visualizer
from keras import models, layers

visualizer(model, file_format='png', settings=settings, view=True)

from IPython.display import Image
Image(filename='graph.png')

# %% [markdown]
# # Train the model

# %%
from sklearn.utils import class_weight

from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping criteria
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Calculate class weights
class_weights = {0: 1.0, 1: 1.0} 

history = model.fit(
    X_train,
    Y_train,
    batch_size=512,
    epochs=50,
    validation_data=(X_test, Y_test),  # Provide validation data
    class_weight=class_weights,  # Apply class weights here
    callbacks=[early_stopping]  # Add early stopping callback
)
# Out:
# Epoch 1/50
# 2024-06-13 15:04:40.268795: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-06-13 15:04:42.008772: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3b194cbb30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-13 15:04:42.008796: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2024-06-13 15:04:42.013536: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-13 15:04:42.025812: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718283882.085520  210552 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1565/1565 [==============================] - 13s 6ms/step - loss: 0.4211 - precision_1: 0.5278 - recall_1: 0.1041 - auc_1: 0.7425 - val_loss: 0.3953 - val_precision_1: 0.5557 - val_recall_1: 0.2825 - val_auc_1: 0.7839
# Epoch 2/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.4003 - precision_1: 0.5696 - recall_1: 0.1920 - auc_1: 0.7790 - val_loss: 0.3943 - val_precision_1: 0.5516 - val_recall_1: 0.3523 - val_auc_1: 0.7945
# Epoch 3/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3937 - precision_1: 0.5834 - recall_1: 0.2305 - auc_1: 0.7882 - val_loss: 0.3893 - val_precision_1: 0.5747 - val_recall_1: 0.3092 - val_auc_1: 0.8008
# Epoch 4/50
# 1565/1565 [==============================] - 10s 6ms/step - loss: 0.3896 - precision_1: 0.5997 - recall_1: 0.2456 - auc_1: 0.7931 - val_loss: 0.3841 - val_precision_1: 0.6021 - val_recall_1: 0.3043 - val_auc_1: 0.8061
# Epoch 5/50
# 1565/1565 [==============================] - 10s 6ms/step - loss: 0.3855 - precision_1: 0.6190 - recall_1: 0.2522 - auc_1: 0.7980 - val_loss: 0.3769 - val_precision_1: 0.6169 - val_recall_1: 0.2947 - val_auc_1: 0.8124
# Epoch 6/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3832 - precision_1: 0.6280 - recall_1: 0.2530 - auc_1: 0.8006 - val_loss: 0.3775 - val_precision_1: 0.6058 - val_recall_1: 0.2981 - val_auc_1: 0.8127
# Epoch 7/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3809 - precision_1: 0.6374 - recall_1: 0.2575 - auc_1: 0.8034 - val_loss: 0.3726 - val_precision_1: 0.6127 - val_recall_1: 0.3215 - val_auc_1: 0.8193
# Epoch 8/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3796 - precision_1: 0.6390 - recall_1: 0.2621 - auc_1: 0.8052 - val_loss: 0.3800 - val_precision_1: 0.6216 - val_recall_1: 0.3223 - val_auc_1: 0.8175
# Epoch 9/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3776 - precision_1: 0.6432 - recall_1: 0.2658 - auc_1: 0.8073 - val_loss: 0.3722 - val_precision_1: 0.6352 - val_recall_1: 0.3138 - val_auc_1: 0.8167
# Epoch 10/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3741 - precision_1: 0.6636 - recall_1: 0.2716 - auc_1: 0.8106 - val_loss: 0.3685 - val_precision_1: 0.6426 - val_recall_1: 0.3217 - val_auc_1: 0.8206
# Epoch 11/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3721 - precision_1: 0.6757 - recall_1: 0.2693 - auc_1: 0.8123 - val_loss: 0.3695 - val_precision_1: 0.6519 - val_recall_1: 0.2944 - val_auc_1: 0.8233
# Epoch 12/50
# 1565/1565 [==============================] - 10s 6ms/step - loss: 0.3709 - precision_1: 0.6816 - recall_1: 0.2698 - auc_1: 0.8135 - val_loss: 0.3844 - val_precision_1: 0.5954 - val_recall_1: 0.3528 - val_auc_1: 0.8137
# Epoch 13/50
# 1565/1565 [==============================] - 9s 5ms/step - loss: 0.3691 - precision_1: 0.6912 - recall_1: 0.2715 - auc_1: 0.8150 - val_loss: 0.3891 - val_precision_1: 0.6292 - val_recall_1: 0.1423 - val_auc_1: 0.7937
# Epoch 14/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3678 - precision_1: 0.7025 - recall_1: 0.2712 - auc_1: 0.8164 - val_loss: 0.3764 - val_precision_1: 0.6222 - val_recall_1: 0.3192 - val_auc_1: 0.8189
# Epoch 15/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3664 - precision_1: 0.7040 - recall_1: 0.2732 - auc_1: 0.8177 - val_loss: 0.3578 - val_precision_1: 0.7091 - val_recall_1: 0.2908 - val_auc_1: 0.8334
# Epoch 16/50
# 1565/1565 [==============================] - 9s 5ms/step - loss: 0.3656 - precision_1: 0.7067 - recall_1: 0.2739 - auc_1: 0.8187 - val_loss: 0.3651 - val_precision_1: 0.6821 - val_recall_1: 0.2895 - val_auc_1: 0.8229
# Epoch 17/50
# 1565/1565 [==============================] - 10s 6ms/step - loss: 0.3646 - precision_1: 0.7132 - recall_1: 0.2747 - auc_1: 0.8196 - val_loss: 0.3626 - val_precision_1: 0.6663 - val_recall_1: 0.3440 - val_auc_1: 0.8232
# Epoch 18/50
# 1565/1565 [==============================] - 11s 7ms/step - loss: 0.3636 - precision_1: 0.7185 - recall_1: 0.2716 - auc_1: 0.8203 - val_loss: 0.3618 - val_precision_1: 0.6748 - val_recall_1: 0.3267 - val_auc_1: 0.8270
# Epoch 19/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3633 - precision_1: 0.7171 - recall_1: 0.2743 - auc_1: 0.8207 - val_loss: 0.3576 - val_precision_1: 0.6785 - val_recall_1: 0.3141 - val_auc_1: 0.8269
# Epoch 20/50
# 1565/1565 [==============================] - 7s 4ms/step - loss: 0.3619 - precision_1: 0.7253 - recall_1: 0.2750 - auc_1: 0.8218 - val_loss: 0.3854 - val_precision_1: 0.6132 - val_recall_1: 0.1930 - val_auc_1: 0.8109
# Epoch 21/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3614 - precision_1: 0.7269 - recall_1: 0.2761 - auc_1: 0.8226 - val_loss: 0.3631 - val_precision_1: 0.7095 - val_recall_1: 0.2895 - val_auc_1: 0.8298
# Epoch 22/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3611 - precision_1: 0.7234 - recall_1: 0.2778 - auc_1: 0.8230 - val_loss: 0.4258 - val_precision_1: 0.5879 - val_recall_1: 0.0938 - val_auc_1: 0.7424
# Epoch 23/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3601 - precision_1: 0.7285 - recall_1: 0.2786 - auc_1: 0.8239 - val_loss: 0.3548 - val_precision_1: 0.7644 - val_recall_1: 0.2700 - val_auc_1: 0.8359
# Epoch 24/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3595 - precision_1: 0.7253 - recall_1: 0.2815 - auc_1: 0.8246 - val_loss: 0.3530 - val_precision_1: 0.7333 - val_recall_1: 0.2876 - val_auc_1: 0.8339
# Epoch 25/50
# 1565/1565 [==============================] - 9s 5ms/step - loss: 0.3591 - precision_1: 0.7288 - recall_1: 0.2805 - auc_1: 0.8250 - val_loss: 0.3585 - val_precision_1: 0.7596 - val_recall_1: 0.2758 - val_auc_1: 0.8315
# Epoch 26/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3587 - precision_1: 0.7278 - recall_1: 0.2824 - auc_1: 0.8256 - val_loss: 0.3565 - val_precision_1: 0.7292 - val_recall_1: 0.2903 - val_auc_1: 0.8333
# Epoch 27/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3580 - precision_1: 0.7328 - recall_1: 0.2786 - auc_1: 0.8264 - val_loss: 0.4045 - val_precision_1: 0.5829 - val_recall_1: 0.1502 - val_auc_1: 0.7713
# Epoch 28/50
# 1565/1565 [==============================] - 10s 7ms/step - loss: 0.3583 - precision_1: 0.7300 - recall_1: 0.2805 - auc_1: 0.8266 - val_loss: 0.3658 - val_precision_1: 0.6703 - val_recall_1: 0.3031 - val_auc_1: 0.8288
# Epoch 29/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3567 - precision_1: 0.7317 - recall_1: 0.2829 - auc_1: 0.8285 - val_loss: 0.4029 - val_precision_1: 0.6072 - val_recall_1: 0.1620 - val_auc_1: 0.7765
# Epoch 30/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3553 - precision_1: 0.7341 - recall_1: 0.2847 - auc_1: 0.8302 - val_loss: 0.3633 - val_precision_1: 0.6312 - val_recall_1: 0.3906 - val_auc_1: 0.8330
# Epoch 31/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3543 - precision_1: 0.7368 - recall_1: 0.2824 - auc_1: 0.8315 - val_loss: 0.3972 - val_precision_1: 0.6266 - val_recall_1: 0.1505 - val_auc_1: 0.7965
# Epoch 32/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3539 - precision_1: 0.7368 - recall_1: 0.2828 - auc_1: 0.8320 - val_loss: 0.3616 - val_precision_1: 0.7141 - val_recall_1: 0.3091 - val_auc_1: 0.8209
# Epoch 33/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3530 - precision_1: 0.7360 - recall_1: 0.2846 - auc_1: 0.8333 - val_loss: 0.3521 - val_precision_1: 0.8169 - val_recall_1: 0.2237 - val_auc_1: 0.8380
# Epoch 34/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3524 - precision_1: 0.7391 - recall_1: 0.2842 - auc_1: 0.8339 - val_loss: 0.3857 - val_precision_1: 0.6091 - val_recall_1: 0.2400 - val_auc_1: 0.8092
# Epoch 35/50
# 1565/1565 [==============================] - 7s 4ms/step - loss: 0.3521 - precision_1: 0.7413 - recall_1: 0.2818 - auc_1: 0.8343 - val_loss: 0.3563 - val_precision_1: 0.7362 - val_recall_1: 0.2577 - val_auc_1: 0.8338
# Epoch 36/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3517 - precision_1: 0.7368 - recall_1: 0.2855 - auc_1: 0.8349 - val_loss: 0.3575 - val_precision_1: 0.7045 - val_recall_1: 0.2959 - val_auc_1: 0.8399
# Epoch 37/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3514 - precision_1: 0.7404 - recall_1: 0.2821 - auc_1: 0.8351 - val_loss: 0.3518 - val_precision_1: 0.6696 - val_recall_1: 0.3286 - val_auc_1: 0.8380
# Epoch 38/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3507 - precision_1: 0.7434 - recall_1: 0.2820 - auc_1: 0.8358 - val_loss: 0.3520 - val_precision_1: 0.7360 - val_recall_1: 0.2814 - val_auc_1: 0.8365
# Epoch 39/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3504 - precision_1: 0.7428 - recall_1: 0.2847 - auc_1: 0.8360 - val_loss: 0.3889 - val_precision_1: 0.5850 - val_recall_1: 0.1909 - val_auc_1: 0.8150
# Epoch 40/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3503 - precision_1: 0.7438 - recall_1: 0.2852 - auc_1: 0.8361 - val_loss: 0.4332 - val_precision_1: 0.5207 - val_recall_1: 0.1067 - val_auc_1: 0.7290
# Epoch 41/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3504 - precision_1: 0.7414 - recall_1: 0.2863 - auc_1: 0.8361 - val_loss: 0.3583 - val_precision_1: 0.7423 - val_recall_1: 0.2524 - val_auc_1: 0.8320
# Epoch 42/50
# 1565/1565 [==============================] - 7s 4ms/step - loss: 0.3497 - precision_1: 0.7439 - recall_1: 0.2843 - auc_1: 0.8369 - val_loss: 0.3568 - val_precision_1: 0.7168 - val_recall_1: 0.3015 - val_auc_1: 0.8363
# Epoch 43/50
# 1565/1565 [==============================] - 8s 5ms/step - loss: 0.3494 - precision_1: 0.7420 - recall_1: 0.2873 - auc_1: 0.8373 - val_loss: 0.3529 - val_precision_1: 0.7560 - val_recall_1: 0.2730 - val_auc_1: 0.8366
# Epoch 44/50
# 1565/1565 [==============================] - 9s 6ms/step - loss: 0.3492 - precision_1: 0.7454 - recall_1: 0.2872 - auc_1: 0.8372 - val_loss: 0.3711 - val_precision_1: 0.5910 - val_recall_1: 0.2111 - val_auc_1: 0.8277
# Epoch 45/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3491 - precision_1: 0.7486 - recall_1: 0.2872 - auc_1: 0.8374 - val_loss: 0.3620 - val_precision_1: 0.6974 - val_recall_1: 0.2669 - val_auc_1: 0.8359
# Epoch 46/50
# 1565/1565 [==============================] - 7s 4ms/step - loss: 0.3489 - precision_1: 0.7437 - recall_1: 0.2896 - auc_1: 0.8377 - val_loss: 0.3587 - val_precision_1: 0.7670 - val_recall_1: 0.2290 - val_auc_1: 0.8328
# Epoch 47/50
# 1565/1565 [==============================] - 7s 5ms/step - loss: 0.3489 - precision_1: 0.7427 - recall_1: 0.2881 - auc_1: 0.8378 - val_loss: 0.3534 - val_precision_1: 0.7190 - val_recall_1: 0.3023 - val_auc_1: 0.8330

# %% [markdown]
# # Save the model

# %%
model.save('phishing_ip_nn_model.keras')

# %% [markdown]
# # Display training results

# %%
def get_metric(history, metric_name):
    if metric_name in history.history:
        return history.history[metric_name]
    elif f"{metric_name}_1" in history.history:
        return history.history[f"{metric_name}_1"]
    elif f"{metric_name}_2" in history.history:
        return history.history[f"{metric_name}_2"]
    else:
        raise KeyError(f"Metric {metric_name} not found in history.")

epoch_losses = get_metric(history, 'loss')
epoch_val_losses = get_metric(history, 'val_loss')
epoch_accuracies = get_metric(history, 'auc')
epoch_val_accuracies = get_metric(history, 'val_auc')
epoch_precisions = get_metric(history, 'precision')
epoch_val_precisions = get_metric(history, 'val_precision')
epoch_recalls = get_metric(history, 'recall')
epoch_val_recalls = get_metric(history, 'val_recall')

# Calculate F1 score
epoch_f1s = [2 * (p * r) / (p + r) for p, r in zip(epoch_precisions, epoch_recalls)]
epoch_val_f1s = [2 * (p * r) / (p + r) for p, r in zip(epoch_val_precisions, epoch_val_recalls)]

import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))

# Plot for Loss
plt.subplot(2, 3, 1)
plt.plot(epoch_losses, linestyle='--', marker='o', color='b', label='Training Loss')
plt.plot(epoch_val_losses, linestyle='--', marker='o', color='r', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.grid(True)

# Plot for AUC (as a proxy for Accuracy)
plt.subplot(2, 3, 2)
plt.plot(epoch_accuracies, linestyle='--', marker='o', color='#ff7f0e', label='Training AUC')
plt.plot(epoch_val_accuracies, linestyle='--', marker='o', color='r', label='Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.title('AUC (Accuracy)')
plt.legend()
plt.grid(True)

# Plot for Precision
plt.subplot(2, 3, 3)
plt.plot(epoch_precisions, linestyle='--', marker='o', color='g', label='Training Precision')
plt.plot(epoch_val_precisions, linestyle='--', marker='o', color='r', label='Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.title('Precision')
plt.legend()
plt.grid(True)

# Plot for Recall
plt.subplot(2, 3, 4)
plt.plot(epoch_recalls, linestyle='--', marker='o', color='c', label='Training Recall')
plt.plot(epoch_val_recalls, linestyle='--', marker='o', color='r', label='Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.title('Recall')
plt.legend()
plt.grid(True)

# Plot for F1 Score
plt.subplot(2, 3, 5)
plt.plot(epoch_f1s, linestyle='--', marker='o', color='m', label='Training F1 Score')
plt.plot(epoch_val_f1s, linestyle='--', marker='o', color='r', label='Validation F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Score')
plt.legend()
plt.grid(True)

plt.suptitle('NN Training Progress', fontsize=16, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Save the figure
plt.savefig('nn_training_progress.png', dpi=500, bbox_inches='tight', pad_inches=0.5)
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Evaluate the model
loss_and_metrics = model.evaluate(X_test, Y_test)
print('Loss = ', loss_and_metrics[0])
print('Accuracy = ', loss_and_metrics[1])

# Generate predictions
Y_pred = model.predict(X_test)
Y_pred = np.round(Y_pred).astype(int)  # Convert probabilities to binary predictions

# Calculate additional metrics
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

# Confusion matrix
cm = confusion_matrix(Y_test, Y_pred)

# False Positive Rate
tn, fp, fn, tp = cm.ravel()
fpr = fp / (fp + tn)

# Display the metrics
print('\n=== RESULTS ===')
print(classification_report(Y_test, Y_pred, target_names=['Benign', 'Malicious'], digits=4))
print('False Positive Rate =', fpr)


# Display the confusion matrix
print('\nConfusion Matrix:')
print(cm)

# Optionally, plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(7, 7))  # Increase figure size for better readability
disp.plot(ax=ax, values_format='d')
for labels in disp.text_:
    for label in labels:
        label.set_fontsize(18) 
plt.show()
# Out:
# 6259/6259 [==============================] - 9s 1ms/step - loss: 0.3518 - precision_1: 0.6696 - recall_1: 0.3286 - auc_1: 0.8380
# Loss =  0.3517903685569763
# Accuracy =  0.6696202754974365
# 6259/6259 [==============================] - 6s 1ms/step
#
# === RESULTS ===
#               precision    recall  f1-score   support
#
#       Benign     0.8635    0.9632    0.9107    163265
#    Malicious     0.6696    0.3286    0.4409     37023
#
#     accuracy                         0.8459    200288
#    macro avg     0.7666    0.6459    0.6758    200288
# weighted avg     0.8277    0.8459    0.8238    200288
#
# False Positive Rate = 0.03676844394083239
#
# Confusion Matrix:
# [[157262   6003]
#  [ 24856  12167]]

# %% [markdown]
# # Feature Importance Analysis

# %%
analyze_feature_importance = True

if analyze_feature_importance:
    
    import shap
    
    # Ensure that X_train and X_test are DataFrames with the correct column names
    # You can set the column names from the 'features' DataFrame like this:
    X_train.columns = features.columns
    X_test.columns = features.columns
    
    n_samples = 1000
    
    # Convert your training set to a NumPy format if it's not already
    background = X_train[:n_samples].to_numpy()
    
    # Use the generic SHAP Explainer interface
    explainer = shap.Explainer(model, background)
    
    # Generate SHAP values for the test set
    shap_values = explainer(X_test[:n_samples].to_numpy())
    
    # Plotting the summary plot for feature importance
    # Use the column names from the 'features' DataFrame as the feature names
    shap.summary_plot(shap_values.values, X_test[:n_samples], feature_names=features.columns, max_display=30)
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
# Exact explainer: 1001it [00:15, 27.06it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# # Validate the model on a separate Validation dataset

# %%
import pyarrow.parquet as pq
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import joblib
from tensorflow.keras.models import load_model
from pandas.core.dtypes import common as com
import numpy as np

def cast_timestamp(df: pd.DataFrame):
    """
    Cast timestamp fields to seconds since epoch.
    """
    for col in df.columns:
        if com.is_timedelta64_dtype(df[col]):
            df[col] = df[col].dt.total_seconds()  # This converts timedelta to float (seconds)
        elif com.is_datetime64_any_dtype(df[col]):
            df[col] = df[col].astype(np.int64) // 10**9  # Converts datetime64 to Unix timestamp (seconds)
    return df

# Load the validation dataset
validation_dataset_filename = '../testdata/validation_phishing.parquet'
df_validation = pq.read_table(validation_dataset_filename).to_pandas()

# Cast timestamps and handle NaNs
df_validation = cast_timestamp(df_validation)
df_validation.fillna(-1, inplace=True)

# Remove disqualified columns
for column in disqualified_columns:
    if column in df_validation.columns:
        df_validation.drop(column, axis=1, inplace=True)

# Preserve only columns of interest
df_validation = df_validation.loc[:, df_validation.columns.str.startswith(prefix) | df_validation.columns.isin(['domain_name', 'label'])]

# Map the labels
df_validation['label'] = df_validation['label'].map({'benign': 0, 'phishing': 1})

# Extract features and labels
X_val = df_validation.drop(['label', 'domain_name'], axis=1)
y_val = df_validation['label']

# Load the scaler
scaler = joblib.load("phishing_ip_nn_scaler.joblib")

# Scale the features
X_val_scaled = scaler.transform(X_val)

# Load the trained model
model = load_model('phishing_ip_nn_model.keras')

# Make predictions
y_prob = model.predict(X_val_scaled).flatten()
y_pred = (y_prob > 0.5).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_val, y_pred)
weighted_accuracy = (accuracy_score(y_val[y_val == 0], y_pred[y_val == 0]) + accuracy_score(y_val[y_val == 1], y_pred[y_val == 1])) / 2
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
false_positive_rate = fp / (fp + tn)

# Display metrics
print(f'Accuracy: {accuracy}')
print(f'Weighted Accuracy: {weighted_accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'False Positive Rate: {false_positive_rate}')

# Display confusion matrix
cm = confusion_matrix(y_val, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['benign', 'phishing'])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# Identify misclassified domain names
misclassified = df_validation[y_val != y_pred]
misclassified_domains = misclassified['domain_name'].tolist()
print(f'Misclassified domains: {misclassified_domains}')
# Out:
# 78/78 [==============================] - 0s 1ms/step
# Accuracy: 0.8495967741935484
# Weighted Accuracy: 0.6408831908831909
# Precision: 0.33114754098360655
# Recall: 0.37407407407407406
# F1 Score: 0.35130434782608694
# False Positive Rate: 0.09230769230769231
# Misclassified domains: ['bt-104190.weeblysite.com', 'plinkos-organization.gitbook.io', 'api.polotno.dev', 'bt-101281-109546.weeblysite.com', '102elki.ru', 'cooking-prod.tuanguwen.com', 'aipanda097.cern.ch', 'steamproxy-hk.imbastar.com', 'pub-d85936a61b694753a8b489011149f7b5.r2.dev', 'clone-airbnb-95now7yy4-qishenghu-s-team.vercel.app', 'www.petanikode.com', 'nasezdravotnictvi.cz', 'm.bi18.cc', 'fodi.caijimoyu.eu.org', '1ict4apf8oom7qga94n31uwt9.trivialextrovertedarrangement.pro', 'livewalletconnect.blogspot.co.il', 'shadowhelix.de', 'remind-servicex.rnd.huawei.com', 'familyshield.opendns.com', 'demo2.mygb.nl', 'www.kamax.cz', 'eglal.cz', 'a.a1d4ef5d.shop', 'att-105809.square.site', 'pub-5a533b66fc614517b92f5493ea982e93.r2.dev', 'att-106770.weeblysite.com', 'nohello.net', 'lodgerbnbaproving550901.com', 'swiatciast.pl', 'my.polar.top', 'support-for-business-open-case-appeal-id-211.vercel.app', 'epel.mirror.wearetriple.com', 'att-106642-104305.weeblysite.com', '3653.mk', 'ticketshop.barcelona', 'pub-feedbe664d4644f987dafae09faf8476.r2.dev', 'snikirakic.wixsite.com', 'fix-to-all-o-issues-verification-form-0submit.vercel.app', 'reviewholdreviewho.wixsite.com', 'mt.tryjumbo.com', 'sentry-internal.temp-mail.io', 'nakitel.com', 'projectelixiros.com', 'www.magicbath.co.in', 'www.yellowpagesalbania.com', 'newscms.windtre.it', 'pub-38b81a81487b452d86ecfd3a873e5640.r2.dev', 'imken.pro', 'www.vectorizer.io', 'cdq.ayb.mybluehost.me', 'expertchat.fx2.io', 'ru.amp.gtp.fyi', 'attnet-104176.weeblysite.com', 'loans837113.life', 'alexadam.sk', 'businesscentersc.pages.dev', 'cfstatic.livesports.mobi', 'bt-business-app-e213d8.webflow.io', 'static.cdn.asset.aparat.cloud', 'video-views-1-m-apply.vercel.app', 'marutiminchem.com', 'derpzilla.net', 'mymemoriesofafuturelife.com', 'f002.backblazeb2.com', 'ambitojuridico.com.br', 'helldivers.io', 'www.immobilienmarkt.li', 'ads.appbundledownload.com', 'arbearssgrounds.wixsite.com', 'techtalker.quickanddirtytips.com', 'nftopensea81.vercel.app', 'www.maltatoday.com.mt', 'download.dokuwiki.org', 'ajfnee.com', 'at-mail-102779.weeblysite.com', 'www.berdichev.biz', 'cf.bmzk.link', 'pub-2b4ee549eae54c3ab7f6c0c2ab24bbf8.r2.dev', 'fuorifrigo.com', 'bankid.org.ua', 'telegprxm.work', 'namaskarmahra.com', 'bannedbookslist.com', 'aidboxes.com', 'pub-0a244b22861d456681dab3d4e696448b.r2.dev', 'zdy.yong96.link', 'account-monetization-violation.vercel.app', 'a6-d9r.pages.dev', 'mswap.bbd.sh', 'tjsis.cz', 'securitycheckios.com', 't0kanpoaket.biz', 'temperate-kangaroo-kw0hgq.mystrikingly.com', 'attnet-106864.weeblysite.com', 'hotvideoustiktok2021.blogspot.com', 'idealni-dum.cz', '22461953.fs1.hubspotusercontent-na1.net', 'wikiparticularization.com', 'barosan77.tripod.com', 'official-telegram-meetandsexx.pages.dev', 'graphicdesign.meta.stackexchange.com', 'www.facebookes.com', 'www.dr-nada.com', 'tok2npo2ket.top', 'www.hooled.it', 'booru.soy', 'yps.link', 'item-list22119.atwebpages.com', 'steinerjj1.wixsite.com', 'at-ts-groovy-site-ab70ba.webflow.io', 'dfdgf46567567.blogspot.ba', 'securchase.verify.englishclassroom.com.br', 'swap.testnet.tabichain.com', 'weather-services.clearbar-api.app', 'todaynews.live', 'beta.creativecirclecdn.com', 'pacificobdpec.ac-page.com', 'cookingpastaready.com', 'momba.dev', 'anticapitalist.club', 'cdn.bongsports.stream', 'linube.com', 'mixrolik.broadviewstream.com', 'mypostercollection.com', 'metamasskluginn.blogspot.it', 'iframe.coomeet.me', 'business2.rti.co.id', '3102jtnu.computer-mod-s.tech', 'openbox5.vercel.app', 'review-ur-current-violations.vercel.app', 'login.cloud.huawei.com', 'matrix.comrademajor.bond', 'hushabye-photography.co.uk', 'magazinelouiza.vercel.app', 'www.boomlings.com', 'down.t0kbnpobket.biz', 'netflix-clone-smoky-nine-84.vercel.app', 'olha.li', '8267556.fs1.hubspotusercontent-na1.net', 'zet2.tvroncdn80.shop', 'www.inmarathi.in', 'truongdaylaixe.vn', 'mysteryboxx-mintnfts403.vercel.app', 'jacekowski.org', 'lk222.infusionsoft.app', '6968579.fs1.hubspotusercontent-na1.net', 'cd ...

# %% [markdown]
# # Make test predictions

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import joblib
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pyarrow import Table

# Load the model and scaler
model = load_model('dga_binary_model.keras')
scaler = joblib.load("dga_binary_scaler.joblib")

# #############################################################
# EDIT this to specify benign / malicious datasets to use     #
# #############################################################
benign_dataset_filenames = [
    '../feature-extraction/floor/benign_2312_anonymized.parquet',
    '../feature-extraction/floor/umbrella_benign_FINISHED.parquet',
]
malicious_dataset_filenames = [
    '../feature-extraction/floor/lex-dga-830k-pick.parquet'
]
# #############################################################
# EDIT this for to set appropriate labels (malware, dga, ...) #
# #############################################################
benign_label = "benign"
malicious_label = "dga"
# #############################################################

def union_tables(tables: [pa.Table]) -> pa.Table:
    union_table = tables[0]
    for table in tables[1:]:
        right_not_in_union = union_table.join(right_table=table, keys='domain_name', join_type='right anti',
                                              coalesce_keys=True, use_threads=True)
        union_table = pa.concat_tables([union_table, right_not_in_union])
    return union_table

# Unify malicious datasets and benign datasets
schema = (pq.read_table(malicious_dataset_filenames[0])).schema # Use the schema from the first malicious filename
benign_tables = [pq.read_table(filename).cast(schema) for filename in benign_dataset_filenames]
malicious_tables = [pq.read_table(filename).cast(schema) for filename in malicious_dataset_filenames]
malicious = union_tables(malicious_tables)
benign = union_tables(benign_tables)

# Convert pyarrow tables to pandas dataframes
df_benign = benign.to_pandas()
df_malicious = malicious.to_pandas()

# Set appropriate labels
df_benign["label"] = benign_label
df_malicious["label"] = malicious_label
class_map = {benign_label: 0, malicious_label: 1}

# Concatentate benign and malicious
test_df = pd.concat([df_benign, df_malicious])

# Handle NaNs
test_df.fillna(-1, inplace=True)


# Take only N random samples
N = 500
test_df = test_df.sample(n=N, random_state=42)

total_predictions = 0
correct_predictions = 0

for index, row in test_df.iterrows():
    domain_name = row['domain_name']
    original_label = row['label']
    
    # Drop "domain_name" and "label" columns
    feature_vector = pd.DataFrame([row])
    feature_vector.drop(columns=['domain_name', 'label'], inplace=True)

     # Scale the feature vector using the loaded scaler
    scaled_feature_vector = scaler.transform(feature_vector)
    
    # Perform prediction
    prediction = model.predict(scaled_feature_vector, verbose=0)
    
    # Extract the predicted class
    predicted_label = "benign" if prediction < 0.5 else "dga"
    
    # Check if the prediction was correct
    if original_label == predicted_label:
        correct_predictions += 1
    
    total_predictions += 1
    
    # Print the result
    result="WRONG"
    if predicted_label == original_label:
        result="OK"
        
    pred_disp = "!!! DGA !!!"
    if predicted_label == "benign":
        pred_disp = "BENIGN"
        
    
    print(f"{result} | {domain_name} ({original_label}), Predicted: {pred_disp}, Prob: {prediction}")

# Calculate accuracy
accuracy = correct_predictions / total_predictions
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[26], line 12
#       9 from pyarrow import Table
#      11 # Load the model and scaler
# ---> 12 model = load_model('dga_binary_model.keras')
#      13 scaler = joblib.load("dga_binary_scaler.joblib")
#      15 # #############################################################
#      16 # EDIT this to specify benign / malicious datasets to use     #
#      17 # #############################################################
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/git/domainradar-training/.venv/lib/python3.11/site-packages/keras/src/saving/legacy/save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at dga_binary_model.keras
